# %%
import pandas as pd

import numpy as np

# %%
data = {
    'chairs': [3, 2, 0, 1], 
    'tables': [0, 3, 7, 2]
}

basket = pd.DataFrame(data)
basket
# Out:
#    chairs  tables
# 0       3       0
# 1       2       3
# 2       0       7
# 3       1       2

# %%
basket_owners = pd.DataFrame(data, index=['Amit', 'Robert', 'Sam','Akash'])

basket_owners

#basket_owners.rename(columns={"chairs": "a", "tables": "c"})
# Out:
#         chairs  tables
# Amit         3       0
# Robert       2       3
# Sam          0       7
# Akash        1       2

# %%
#reading file from URL online

#https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv

import pandas as pd

df = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv')
df
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
#https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv

#delimiter correction

abc = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
#https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv

#Error analysis
#SyntaxError: EOL while scanning string literal
#usage of forward slashes

abc = pd.read_csv('https://gist.git\
hubusercontent.com/michhar/2dfd2de0d4f8727\
f873422c5d959fff5/raw/ff414a1bcfcba32481\
e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')
abc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
import os
os.chdir('C:\\Users\\Deepak\\Desktop\\imarticus\\datafiles')

#use all column names instead of just 3 below, else remaining columns will become part of INDEX column
colname=['age','bmi','fare'] #TBD ??

df = pd.read_csv('titanic_noheader.csv',header=None,names=colname)
#df = pd.read_csv('titanic.csv')

df
# Out:
#                                                                     age  bmi  \
# 0 3 Mr. Owen Harris Braund                             male   22.0    1    0
# 1 1 Mrs. John Bradley (Florence Briggs Thayer) Cumings female 38.0    1    0
#   3 Miss. Laina Heikkinen                              female 26.0    0    0
#   1 Mrs. Jacques Heath (Lily May Peel) Futrelle        female 35.0    1    0
# 0 3 Mr. William Henry Allen                            male   35.0    0    0
# ...                                                                 ...  ...
#   2 Rev. Juozas Montvila                               male   27.0    0    0
# 1 1 Miss. Margaret Edith Graham                        female 19.0    0    0
# 0 3 Miss. Catherine Helen Johnston                     female 7.0     1    2
# 1 1 Mr. Karl Howell Behr                               male   26.0    0    0
# 0 3 Mr. Patrick Dooley                                 male   32.0    0    0
#
#                                                                        fare
# 0 3 Mr. Owen Harris Braund                             male   22.0   7.2500
# 1 1 Mrs. John Bradley (Florence Briggs Thayer) Cumings female 38.0  71.2833
#   3 Miss. Laina Heikkinen                              female 26.0   7.9250
#   1 Mrs. Jacques Heath (Lily May Peel) Futrelle        female 35.0  53.1000
# 0 3 Mr. William Henry Allen                            male   35.0   8.0500
# ...                                                                     ...
#   2 Rev. Juozas Montvila                               male   27.0  13.0000
# 1 1 Miss. Margaret Edith Graham                        female 19.0  30.0000
# 0 3 Miss. Catherine Helen Johnston                     female 7.0   23.4500
# 1 1 Mr. Karl Howell Behr                               male   26.0  30.0000
# 0 3 Mr. Patrick Dooley                                 male   32.0   7.7500
#
# [887 rows x 3 columns]

# %%
df.head()
df.tail(10)
#df.shape
# Out:
#                                                        age      bmi
# 0 3 Mr. Johann Markun                   male   33.0 0    0   7.8958
#     Miss. Gerda Ulrika Dahlberg         female 22.0 0    0  10.5167
#   2 Mr. Frederick James Banfield        male   28.0 0    0  10.5000
#   3 Mr. Henry Jr Sutehall               male   25.0 0    0   7.0500
#     Mrs. William (Margaret Norton) Rice female 39.0 0    5  29.1250
#   2 Rev. Juozas Montvila                male   27.0 0    0  13.0000
# 1 1 Miss. Margaret Edith Graham         female 19.0 0    0  30.0000
# 0 3 Miss. Catherine Helen Johnston      female 7.0  1    2  23.4500
# 1 1 Mr. Karl Howell Behr                male   26.0 0    0  30.0000
# 0 3 Mr. Patrick Dooley                  male   32.0 0    0   7.7500

# %%
new_df=df[['Survived','Age']]
new_df
df
features=df.drop(['Survived','Age'],axis=1)
new_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-0d31b34a60cd> in <module>
# ----> 1 new_df=df[['Survived','Age']]
#       2 new_df
#       3 df
#       4 features=df.drop(['Survived','Age'],axis=1)
#       5 new_df
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda33\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\anaconda33\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Survived', 'Age'], dtype='object')] are in the [columns]"

# %%
#EDA
#desciptive stats
features.describe()

# %%
#vertical split

#df.shape
new_df=df[['Survived','Age']]
new_df


features=df.drop(['Survived','Age'],axis=1) #try inline=True
features

# %%
#horizontal split
#data filters
df_age=df[df.Age>20]
df_f=df[df.Sex=='female']


#data validation
print(df.shape)
print(df_m.shape)
print(df_f.shape)
df_age

# %%
#output file with header
df_age.to_csv('new_file66.csv')


#output file without header
df_age.to_csv('new_file666.csv',header=False)

# %%
#help section
??df.to_csv

# %%
#analytics
#aggregation
df.groupby('Pclass').count()

# %%
#analytics
#aggregation on multiple fields/columns

df.groupby(['Pclass','Survived']).count()
