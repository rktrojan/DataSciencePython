# %%
#import statsmodels
import statsmodels.api as sm

import numpy as np

import pandas as pd

import statsmodels.api as sm

# %%
dt1=sm.datasets.cancer.load_pandas().data
type(dt1)
dt1.describe()
# Out:
#            cancer    population
# count  301.000000    301.000000
# mean    39.857143  11288.056478
# std     50.977801  13780.010088
# min      0.000000    445.000000
# 25%     11.000000   2935.000000
# 50%     22.000000   6445.000000
# 75%     48.000000  13989.000000
# max    360.000000  88456.000000

# %%
ll=sm.datasets.longley.load_pandas()
dt=sm.datasets.longley.load_pandas().data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x=ll.POP
y=ll.TOTEMP
plt.plot(x,y)


#plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-137f12d97e1f> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 x=ll.POP
#       4 y=ll.TOTEMP
#       5 plt.plot(x,y)
#
# AttributeError: 'Dataset' object has no attribute 'POP'

# %%
sm.datasets.longley.DESCRLONG

# %%
#dt=sm.datasets.longley.load_pandas().data

df = sm.datasets.get_rdataset("Arthritis", "vcd").data
#https://github.com/vincentarelbundock/Rdatasets/tree/master/csv/vcd
df.head()
# Out:
#    ID Treatment   Sex  Age Improved
# 0  57   Treated  Male   27     Some
# 1  46   Treated  Male   29     None
# 2  77   Treated  Male   30     None
# 3  17   Treated  Male   32   Marked
# 4  36   Treated  Male   46   Marked

# %%
import pandas as pd
#https://github.com/vincentarelbundock/Rdatasets/tree/master/csv/vcd/Arthritis.csv
pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/vcd/Arthritis.csv')

# %%
??sm.datasets.get_rdataset

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 10000)

# %%
#??sm.datasets.get_rdataset
df

# %%
#dt=sm.datasets.longley.load_pandas().data

df = sm.datasets.get_rdataset("Arthritis", "vcd").data
#https://github.com/vincentarelbundock/Rdatasets/tree/master/csv/vcd
df.head()

data = df[["Treatment", "Improved"]]

data
# Out:
#    Treatment Improved
# 0    Treated     Some
# 1    Treated     None
# 2    Treated     None
# 3    Treated   Marked
# 4    Treated   Marked
# 5    Treated   Marked
# 6    Treated     None
# 7    Treated   Marked
# 8    Treated     None
# 9    Treated     None
# 10   Treated     None
# 11   Treated     Some
# 12   Treated     None
# 13   Treated   Marked
# 14   Treated     None
# 15   Treated     None
# 16   Treated     Some
# 17   Treated     None
# 18   Treated   Marked
# 19   Treated     None
# 20   Treated   Marked
# 21   Treated   Marked
# 22   Treated   Marked
# 23   Treated   Marked
# 24   Treated   Marked
# 25   Treated   Marked
# 26   Treated   Marked
# 27   Treated     None
# 28   Treated   Marked
# 29   Treated   Marked
# 30   Treated   Marked
# 31   Treated   Marked
# 32   Treated     Some
# 33   Treated   Marked
# 34   Treated   Marked
# 35   Treated   Marked
# 36   Treated     Some
# 37   Treated   Marked
# 38   Treated     None
# 39   Treated     Some
# ...

# %%
table = sm.stats.Table.from_data(data)
print(table)
# Out:
# A 2x3 contingency table with counts:
# [[ 7. 29.  7.]
#  [21. 13.  7.]]

# %%
newdata=ll
newdata
# Out:
# <class 'statsmodels.datasets.utils.Dataset'>

# %% [markdown]
# # Machine Learning starts here

# %%
#MODELs

#features
X=newdata.exog
X=X.drop(['POP'],axis=1)

# %%
#target
y=newdata.endog

#actual model building
model = sm.OLS(y, X)

results = model.fit()

results.summary2()
# Out:
# C:\Users\Deepak\anaconda33\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ...
# Model:                  OLS              Adj. R-squared (uncentered): 1.000
# Dependent Variable:     TOTEMP           AIC:                         247.5833
# Date:                   2020-06-07 16:50 BIC:                         251.4462
# No. Observations:       16               Log-Likelihood:              -118.79
# Df Model:               5                F-statistic:                 5.719e+04
# Df Residuals:           11               Prob (F-statistic):          6.88e-24
# R-squared (uncentered): 1.000            Scale:                       2.3937e+05
# ------------------------------------------------------------------------------------
# ...

# %%
print('Parameters: ', results.params)
#\n
print('R2: ', results.rsquared)
# Out:
# Parameters:  GNPDEFL    54.616059
# GNP         0.034313
# UNEMP      -0.870083
# ARMED      -0.555167
# YEAR       25.933029
# dtype: float64
# R2:  0.999961530442224

# %%
#errors

predicted=results.predict()
error=y-predicted
RMSE
MSE
MASE
#print(y)
#newdata.data
# Out:
# 0      191.735514
# 1     -299.476437
# 2       56.582649
# 3     -204.311441
# 4     -369.752181
# 5     -570.409133
# 6       -6.413256
# 7      139.765485
# 8      373.305129
# 9     1077.324413
# 10     412.875902
# 11     -32.196336
# 12    -126.174862
# 13      68.354357
# 14     -13.301982
# 15    -698.410474
# Name: TOTEMP, dtype: float64

# %%
results.save('model.pkl')

#results2=sm.load('model.pkl')
#pickel files in python

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Deepak'
