# %%
counter = 100          # An integer assignment
miles   = 1000.999       # A floating point
name    = "John"       # A string character



print( counter)
print (miles)
print( name)

a = b = c = 1

a,b,c = 1,2,"john"


str = 'Hello World!'

arr=str.split(' ')

#array of character

print (str          )# Prints complete (string
print (str[0]       )# Prints first character of the (string
print (str[2:5]     )# Prints characters starting from 3rd to 5th
print (str[2:]      )# Prints (string starting from 3rd character
print (str * 2      )# Prints (string two times
print (str + " " + "TEST" )# Prints concatenated (string
# Out:
# 100
# 1000.0
# John
# Hello World!
# H
# llo
# llo World!
# Hello World!Hello World!
# Hello World! TEST

# %%
str = 'Hello World!'

arr=str.split(' ')


str=arr[1]
str[::-1]
# Out:
# '!dlroW'

# %%
str[0]=8
str[0]
#a,b,c = 1,2, 88
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a726d0105198> in <module>
# ----> 1 str[0]=8
#       2 str[0]
#       3 #a,b,c = 1,2, 88
#
# TypeError: 'str' object does not support item assignment

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-abbd5c576788> in <module>
#       1 xyz=Student()
# ----> 2 xyz.displayStudent()
#       3
#
# AttributeError: 'Student' object has no attribute 'displayStudent'

# %%
print(str)
print(str[::-1])
# Out:
# Hello World!
# !dlroW olleH

# %%
str = 'Hello World!'

array of character

print (str          )# Prints complete (string
print (str[0]       )# Prints first character of the (string
print (str[2:5]     )# Prints characters starting from 3rd to 5th
print (str[2:]      )# Prints (string starting from 3rd character
print (str * 2      )# Prints (string two times
print (str + " " + "TEST" )# Prints concatenated (string
# Out:
#   File "<ipython-input-4-11792ce34412>", line 3
#     array of character
#            ^
# SyntaxError: invalid syntax
