# %%
from matplotlib import pyplot as plt
#same as above
import matplotlib.pyplot as plt


#########
import numpy as np
import math #needed for definition of pi
#x = np.arange(0, math.pi*2, 0.05)
x = np.arange(0,6, 0.05)

y1 =np.sin(x)
#########
y2=np.cos(x)

plt.plot(x,y1,'g--')

plt.plot(x, y2, 'y*')
#plt.plot(x, -np.sin(x), 'g--')

plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')


plt.show()

# %%
y1
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
import math #needed for definition of pi


x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

#subplot is like array
plt.subplot(521)
plt.plot(x,y)

plt.subplot(523)

plt.plot(x, np.cos(x), 'r-')


plt.subplot(529)

plt.plot(x, -np.cos(x), 'r-')


plt.show()

# %%
# %matplotlib inline
import os
os.getcwd()
# Out:
# 'C:\\Users\\Deepak'

# %% [markdown]
# # EDA starts here

# %%
import pandas as pd
#help
#??pd.read_csv

df = pd.read_csv('https://raw.githubusercontent.com/rktrojan/DataSciencePython/master/DataFiles/Pokemon.csv', index_col=0,encoding= 'unicode_escape')

df.head()

#df.describe()
#pandas_profiling
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
'NaN'!=NaN

--blank
=NaN----None
--string datatype--varchar   
char-b

boolean - True and False
# Out:
#   File "<ipython-input-6-a5b728be3620>", line 4
#     =NaN----None
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
#df.isnull().sum()
#df.drop([Type 2])

#df['Type 2'].fillna(0,inplace=True)
df['HP'].fillna(np.mean(df['HP']),inplace=True)
#mutable object
#imutable object

np.mean(df['HP'])

NULL values/missinng
0/1
mean/meadian/mode--stats
model -LR and MA

# %%
df['Type 1'].replace('G','Grass',inplace=True)
df['Type 1']

# %%
df['Type 1']

# %%
df1=pd.DataFrame([1,1,2,2,2,3])

df1

#df1.duplicated().sum()

# %%
df1=pd.DataFrame([[1,1,2,2,2,3],[1,1,2,2,2,3]])

df1

df1.duplicated()

# %%
df1=pd.DataFrame([[1,1],[1,2],[1,2]],columns=['student_id','Batch'])

df1.duplicated()

final_df=df1.drop_duplicates()
df1.drop_duplicates()

# %%
#df1=pd.DataFrame([[1,1],[1,2],[1,2]],columns=['student_id','Batch'])

#df1.duplicated()

#final_df=df1.drop_duplicates()
final_df.duplicated(['student_id'])
final_df=final_df.drop_duplicates(['student_id'])
#final_df

# %%
#NaN
#None
#NULL

import seaborn as sns
#sns.lmplot(x='Attack', y='Defense', data=df,fit_reg=True)
sns.countplot(df.Legendary)

# %%
x=df['Attack']
y=df['Defense']


plt.scatter(x,y)

df
#univariate vs bivariate

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage')   # Color by evolution stage

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage')   # Color by evolution stage

# %%
sns.boxplot(data=df)

# %%
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)
 
# New boxplot using stats_df
sns.boxplot(data=stats_df)

# %%
#first calculate the correlation value
abc=stats_df.corr()
abc
sns.heatmap(abc,annot=True)
#annot=annotation for showin value on heatmap

#geoplots for plots on maps using latitude and longitudes

# %%
#print(stats_df.isnull)
#sns.heatmap(stats_df)

stats_df.fillna(0,inplace=True)
stats_df.isnull()

stats_df.duplicated()
stats_df.drop_duplicates()

# %%
#ax = sns.heatmap(stats_df, annot=True, fmt="d")

# %%
flights = sns.load_dataset("flights")
flights

# %%
flights_p=flights.pivot("month", "year", "passengers")
flights_p

# %%
ax = sns.heatmap(flights_p)

# %%
ax = sns.heatmap(flights_p, annot=True, fmt="d")

# %% [markdown]
# # loop over DF for charts

# %%
import seaborn as sns

df.columns
df.dtypes

# %%
import seaborn as sns

for i in df.columns:
    
        if (df[i].dtypes)=='int64':
            plt.figure(figsize=(20,30))
            sns.distplot(df[i])
            plt.show()
            
            
        else:
            sns.countplot(df[i])
            plt.show()

# %%
df.dtypes

# %%
age=[1,2,34,44]

sal=[11,22,33,3]


import matplotlib.pyplot as plt
plt.scatter(age,sal)
