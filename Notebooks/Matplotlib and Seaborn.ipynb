# %%
from matplotlib import pyplot as plt
#same as above
import matplotlib.pyplot as plt


#########
import numpy as np
import math #needed for definition of pi
#x = np.arange(0, math.pi*2, 0.05)
x = np.arange(0,6, 0.05)

y1 =np.sin(x)
#########
y2=np.cos(x)

plt.plot(x,y1,'g--')

plt.plot(x, y2, 'y*')
#plt.plot(x, -np.sin(x), 'g--')

plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-16bf0fbce900> in <module>
# ----> 1 from matplotlib import pyplot as plt
#       2 #same as above
#       3 import matplotlib.pyplot as plt
#       4
#       5
#
# ~\anaconda33\lib\site-packages\matplotlib\pyplot.py in <module>
#      30 from cycler import cycler
#      31 import matplotlib
# ---> 32 import matplotlib.colorbar
#      33 import matplotlib.image
#      34 from matplotlib import rcsetup, style
#
# ~\anaconda33\lib\site-packages\matplotlib\colorbar.py in <module>
#      25
#      26 import matplotlib as mpl
# ---> 27 import matplotlib.artist as martist
#      28 import matplotlib.cbook as cbook
#      29 import matplotlib.collections as collections
#
# ModuleNotFoundError: No module named 'matplotlib.artist'

# %%
y1

# %%
from matplotlib import pyplot as plt
import numpy as np
import math #needed for definition of pi


x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

#subplot is like array
plt.subplot(521)
plt.plot(x,y)

plt.subplot(523)

plt.plot(x, np.cos(x), 'r-')


plt.subplot(529)

plt.plot(x, -np.cos(x), 'r-')


plt.show()

# %%
# %matplotlib inline
import os
os.getcwd()

# %% [markdown]
# # EDA starts here

# %%
import pandas as pd
#help
#??pd.read_csv

df = pd.read_csv('https://raw.githubusercontent.com/rktrojan/DataSciencePython/master/DataFiles/Pokemon.csv', index_col=0,encoding= 'unicode_escape')

df.head()

#df.describe()
#pandas_profiling
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
'NaN'!=NaN

--blank
=NaN----None
--string datatype--varchar   
char-b

boolean - True and False

# %%
import numpy as np

# %%
#df.isnull().sum()
#df.drop([Type 2])

#df['Type 2'].fillna(0,inplace=True)
df['HP'].fillna(np.mean(df['HP']),inplace=True)
#mutable object
#imutable object

np.mean(df['HP'])

NULL values/missinng
0/1
mean/meadian/mode--stats
model -LR and MA

# %%
df['Type 1'].replace('G','Grass',inplace=True)
df['Type 1']

# %%
df['Type 1']

# %%
df1=pd.DataFrame([1,1,2,2,2,3])

df1

#df1.duplicated().sum()

# %%
df1=pd.DataFrame([[1,1,2,2,2,3],[1,1,2,2,2,3]])

df1

df1.duplicated()

# %%
df1=pd.DataFrame([[1,1],[1,2],[1,2]],columns=['student_id','Batch'])

df1.duplicated()

final_df=df1.drop_duplicates()
df1.drop_duplicates()

# %%
#df1=pd.DataFrame([[1,1],[1,2],[1,2]],columns=['student_id','Batch'])

#df1.duplicated()

#final_df=df1.drop_duplicates()
final_df.duplicated(['student_id'])
final_df=final_df.drop_duplicates(['student_id'])
#final_df

# %%
#NaN
#None
#NULL

import seaborn as sns
#sns.lmplot(x='Attack', y='Defense', data=df,fit_reg=True)
sns.countplot(df.Legendary)

# %%
x=df['Attack']
y=df['Defense']


plt.scatter(x,y)

df
#univariate vs bivariate
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage')   # Color by evolution stage

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage')   # Color by evolution stage

# %%
sns.boxplot(data=df)

# %%
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)
 
# New boxplot using stats_df
sns.boxplot(data=stats_df)

# %%
#first calculate the correlation value
abc=stats_df.corr()
abc
sns.heatmap(abc,annot=True)
#annot=annotation for showin value on heatmap

#geoplots for plots on maps using latitude and longitudes

# %%
#print(stats_df.isnull)
#sns.heatmap(stats_df)

stats_df.fillna(0,inplace=True)
stats_df.isnull()

stats_df.duplicated()
stats_df.drop_duplicates()

# %%
#ax = sns.heatmap(stats_df, annot=True, fmt="d")

# %%
flights = sns.load_dataset("flights")
flights

# %%
flights_p=flights.pivot("month", "year", "passengers")
flights_p

# %%
ax = sns.heatmap(flights_p)

# %%
ax = sns.heatmap(flights_p, annot=True, fmt="d")

# %% [markdown]
# # loop over DF for charts

# %%
import seaborn as sns

df.columns
df.dtypes
# Out:
# Name         object
# Type 1       object
# Type 2       object
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# Sp. Atk       int64
# Sp. Def       int64
# Speed         int64
# Stage         int64
# Legendary      bool
# dtype: object

# %%
import seaborn as sns

for i in df.columns:
    
        if (df[i].dtypes)=='int64':
            plt.figure(figsize=(20,30))
            sns.distplot(df[i])
            plt.show()
            
            
        else:
            sns.countplot(df[i])
            plt.show()
# Out:
# C:\Users\Deepak\anaconda33\envs\reports\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Deepak\anaconda33\envs\reports\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df.dtypes
# Out:
# Name         object
# Type 1       object
# Type 2       object
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# Sp. Atk       int64
# Sp. Def       int64
# Speed         int64
# Stage         int64
# Legendary      bool
# dtype: object
