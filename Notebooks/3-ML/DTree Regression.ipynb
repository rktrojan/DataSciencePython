# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_boston

#data object
dt= load_boston()

X=dt.data
Y=dt.target

# %%
df_x=pd.DataFrame(X,columns=dt.feature_names)
df_x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
df_y=pd.DataFrame(Y,columns=["target"])
df_y
# Out:
#      target
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
# ..      ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(df_x,df_y, test_size=0.2) #

# %% [markdown]
# # Model train and test

# %%
# import the regressor 
from sklearn.tree import DecisionTreeRegressor  
  
# create a regressor object 
regressor = DecisionTreeRegressor(random_state = 0, 
                                 )  
  
#.fit(X_train,y_train)
regressor.fit(X_train,y_train)

regressor
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
print(regressor.feature_importances_)

print(dt.feature_names)
# Out:
# [7.39880234e-02 5.74365422e-03 5.72160094e-03 1.82339234e-04
#  2.71812670e-02 5.89079503e-01 1.98387036e-02 4.67398766e-02
#  2.29987418e-03 1.53533517e-02 1.10400679e-02 8.26695495e-03
#  1.94564783e-01]
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
regressor.get_depth()
# Out:
# 18

# %%
# PLOT DTREE

# %%
#import this for tree plot
import matplotlib.pyplot as plt
from sklearn import tree

# %%
tree.plot_tree(regressor,feature_names = dt.feature_names)
# Out:
# [Text(167.4, 190.26, 'RM <= 6.941\nmse = 78.199\nsamples = 404\nvalue = 22.012'),
#  Text(83.7, 135.9, 'LSTAT <= 14.4\nmse = 35.212\nsamples = 345\nvalue = 19.548'),
#  Text(41.85, 81.53999999999999, 'RM <= 6.543\nmse = 19.402\nsamples = 197\nvalue = 23.012'),
#  Text(20.925, 27.180000000000007, 'mse = 14.07\nsamples = 156\nvalue = 21.778'),
#  Text(62.775000000000006, 27.180000000000007, 'mse = 11.851\nsamples = 41\nvalue = 27.707'),
#  Text(125.55000000000001, 81.53999999999999, 'CRIM <= 7.465\nmse = 19.017\nsamples = 148\nvalue = 14.936'),
#  Text(104.625, 27.180000000000007, 'mse = 10.365\nsamples = 92\nvalue = 16.986'),
#  Text(146.475, 27.180000000000007, 'mse = 14.996\nsamples = 56\nvalue = 11.57'),
#  Text(251.10000000000002, 135.9, 'RM <= 7.515\nmse = 86.361\nsamples = 59\nvalue = 36.424'),
#  Text(209.25, 81.53999999999999, 'CRIM <= 7.393\nmse = 48.626\nsamples = 38\nvalue = 31.811'),
#  Text(188.32500000000002, 27.180000000000007, 'mse = 23.787\nsamples = 35\nvalue = 33.303'),
#  Text(230.175, 27.180000000000007, 'mse = 9.307\nsamples = 3\nvalue = 14.4'),
#  Text(292.95, 81.53999999999999, 'RAD <= 16.0\nmse = 46.45\nsamples = 21\nvalue = 44.771'),
#  Text(272.02500000000003, 27.180000000000007, 'mse = 21.309\nsamples = 20\nvalue = 45.915'),
#  Text(313.875, 27.180000000000007, 'mse = 0.0\nsamples = 1\nvalue = 21.9')]

# %%
#more plots

tree.plot_tree(regressor,feature_names = dt.feature_names)

#!conda install python-graphviz

# %%
from sklearn import tree

tree.export_graphviz(regressor,out_file = 'dtree', 
                     feature_names = dt.feature_names,label='all',
                     
    filled=True,
    leaves_parallel=True)
#??tree.export_graphviz

import os
os.chdir("C:/Users/Admin")
# Out:
# 'C:\\Users\\Admin'

# %%
#jupyter plotting

from graphviz import Source



graph1 = Source(

tree.export_graphviz(regressor,out_file = None, 
                     feature_names = dt.feature_names,label='all',
    filled=True,
    leaves_parallel=True))


graph1

# %%
#assignment operator
a=1
a+=5
print(a)
# Out:
# ';'

# %%
import os

os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
from IPython.display import SVG

SVG(graph.pipe(format='svg'))

# %%
# PREDICTIONS

13
1 13

# %%
y_pred1 = regressor.predict(X_test)
y_pred1



#GINI IMPURITY---should be less

#MULTIWAY TREE ---CHAID models
#BINARY---------CART
# Out:
# array([31. , 22.8, 19.9, 22.4, 50. , 17.8, 19. , 28.6, 19.1, 31. , 20.2,
#        21.7, 45.4, 28.6, 11.9, 28.7, 12.7, 27.5, 19.6, 25.1, 28.7, 23.8,
#        10.2, 23.4, 14.1, 24.8, 38.7, 23.1, 28.7, 17.8, 24.4, 23.2, 20.1,
#        17.8, 22.9, 50. , 20.2, 26.6, 26.5, 22.8, 18.6, 24.5, 22.7, 21.4,
#         9.5, 23.6, 10.2, 50. , 20.3, 21.8, 21.1, 19.5, 23.7, 18.5, 31.7,
#        22. , 14.6, 26.6, 19.6, 18.9, 23.4, 28.7, 21.1, 16.7, 50. , 17.1,
#        22.5, 24.4, 20.6, 34.9, 23.6,  7. , 34.9, 36.2, 11.7, 23.3,  7. ,
#        23.1, 21.7, 17.2, 32.5, 20.8, 45.4, 24.4, 17.1, 24.7, 14.9, 31. ,
#        21.1, 13.1, 23.8, 22.5, 17.2, 23.8, 37.9, 36. , 23.3, 28.6, 19.6,
#        22.8, 14.9, 20.1])

# %%
#Error --- 23 == 23-6 or 23+6
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 256  0.01538  90.0   3.75   0.0  0.394  7.454  34.2  6.3361   3.0  244.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889   1.0  273.0
# 486  5.69175   0.0  18.10   0.0  0.583  6.114  79.8  3.5459  24.0  666.0
# 314  0.36920   0.0   9.90   0.0  0.544  6.567  87.3  3.6023   4.0  304.0
# 163  1.51902   0.0  19.58   1.0  0.605  8.375  93.9  2.1620   5.0  403.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 301  0.03537  34.0   6.09   0.0  0.433  6.590  40.4  5.4917   7.0  329.0
# 130  0.34006   0.0  21.89   0.0  0.624  6.458  98.9  2.1185   4.0  437.0
# 369  5.66998   0.0  18.10   1.0  0.631  6.683  96.8  1.3567  24.0  666.0
# 430  8.49213   0.0  18.10   0.0  0.584  6.348  86.1  2.0527  24.0  666.0
# 359  4.26131   0.0  18.10   0.0  0.770  6.112  81.3  2.5091  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 256     15.9  386.34   3.11
# 504     21.0  393.45   6.48
# 486     20.2  392.68  14.98
# 314     18.4  395.69   9.28
# 163     14.7  388.45   3.32
# ..       ...     ...    ...
# 301     16.1  395.75   9.50
# 130     21.2  395.04  12.60
# 369     20.2  375.33   3.73
# 430     20.2   83.45  17.64
# 359     20.2  390.74  12.67
#
# [102 rows x 13 columns]

# %%
#MODEL EVALAUTION

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt

import matplotlib.pyplot as plt

# %matplotlib inline



actual=y_test

#RMSE=sqrt(MSE)

# %%
error1 = sqrt(mean_squared_error(actual,y_pred1)) #calculate rmse
error1



#KNN-5.515006380894805

#DTREE-- 4.481213508616157
#4.867565069212129 --- D=2
6.3916990637085
# Out:
# 6.3916990637085

# %%
from sklearn import feature_selection as fs

from sklearn import feature_extraction as fx


from sklearn import preprocessing as pp
#MICE

# %%
from sklearn import preprocessing as pp
#MICE

# %%
from sklearn import metrics
print("Accuracy:",metrics.r2_score(y_test, y_pred1))


#r2 metric=
#accuracy=TP+TN/TP+TN+FN+FP

#DTREE--Accuracy: 0.8296736761321832===   D=21

#0.7268413297007621  --- D=18
#Accuracy: 0.6970626004890764 -- D=2
# Out:
# Accuracy: 0.7268413297007621

# %%
#GRID SEARCH CV

# %%
#GridSearch CV

from sklearn.model_selection import GridSearchCV
params = {'max_depth':[1,2,3,5,7,9,11,12,13,18,21]}

#11
#1 model * k folds==5 score----  mean of these 5 scores
#2 model * k folds==5 score----  mean of these 5 scores
#..
#..
#..
#11 model * k folds ==5 score----  mean of these 5 scores

model = GridSearchCV(regressor, params, cv=5)
model.fit(X_train,y_train)

#model.predict(X_test)
# Out:
# array([33.30285714, 27.70731707, 16.98586957, 27.70731707, 45.915     ,
#        16.98586957, 21.77820513, 27.70731707, 11.56964286, 33.30285714,
#        21.77820513, 16.98586957, 45.915     , 27.70731707, 11.56964286,
#        33.30285714, 11.56964286, 21.77820513, 21.77820513, 27.70731707,
#        27.70731707, 21.77820513, 11.56964286, 21.77820513, 16.98586957,
#        27.70731707, 45.915     , 21.77820513, 33.30285714, 16.98586957,
#        21.77820513, 16.98586957, 21.77820513, 16.98586957, 21.77820513,
#        21.77820513, 21.77820513, 27.70731707, 27.70731707, 27.70731707,
#        21.77820513, 21.77820513, 21.77820513, 21.77820513, 11.56964286,
#        21.77820513, 11.56964286, 45.915     , 21.77820513, 21.77820513,
#        21.77820513, 16.98586957, 21.77820513, 21.77820513, 33.30285714,
#        21.77820513, 11.56964286, 27.70731707, 21.77820513, 16.98586957,
#        21.77820513, 27.70731707, 21.77820513, 11.56964286, 45.915     ,
#        11.56964286, 21.77820513, 21.77820513, 21.77820513, 33.30285714,
#        21.77820513, 16.98586957, 33.30285714, 33.30285714, 11.56964286,
#        21.77820513, 11.56964286, 16.98586957, 21.77820513, 11.56964286,
#        27.70731707, 21.77820513, 45.915     , 21.77820513, 21.77820513,
#        21.77820513, 16.98586957, 33.30285714, 21.77820513, 16.98586957,
#        21.77820513, 21.77820513, 11.56964286, 21.77820513, 33.30285714,
#        33.30285714, 21.77820513, 27.70731707, 21.77820513, 27.70731707,
#        11.56964286, 21.77820513])

# %%
#selecting best hyper-parameters

# %%
model.cv_results_
# Out:
# {'mean_fit_time': array([0.01139851, 0.01898651, 0.01359549, 0.0107955 , 0.01172605,
#         0.01179156, 0.01219316, 0.01059618, 0.01219125, 0.01179447,
#         0.01318827]),
#  'std_fit_time': array([0.00256979, 0.00704193, 0.00567377, 0.00416397, 0.00328691,
#         0.00470835, 0.00495215, 0.00412391, 0.00495015, 0.00401745,
#         0.00376058]),
#  'mean_score_time': array([0.0121892 , 0.0113956 , 0.0067945 , 0.00700054, 0.00699401,
#         0.00659418, 0.00539818, 0.00419545, 0.00599461, 0.00519576,
#         0.00479937]),
#  'std_score_time': array([0.00748566, 0.00499866, 0.00465631, 0.00380102, 0.00199664,
#         0.00538278, 0.00300589, 0.00247541, 0.00303196, 0.00171744,
#         0.00222673]),
#  'param_max_depth': masked_array(data=[1, 2, 3, 5, 7, 9, 11, 12, 13, 18, 21],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 1},
#   {'max_depth': 2},
#   {'max_depth': 3},
#   {'max_depth': 5},
#   {'max_depth': 7},
#   {'max_depth': 9},
#   {'max_depth': 11},
#   {'max_depth': 12},
#   {'max_depth': 13},
#   {'max_depth': 18},
#   {'max_depth': 21}],
#  'split0_test_score': array([0.49294851, 0.78970217, 0.82895797, 0.80324159, 0.85004052,
#         0.80239736, 0.64049094, 0.81017924, 0.73270867, 0.7870922 ,
#         0.6010926 ]),
#  'split1_test_score': array([ 0.1423734 ,  0.36535038,  0.20112862, -0.04976712, -0.10644717,
#         -0.05550849, -0.00274204,  0.09510759,  0.10737657, -0.12454565,
#         -0.12454565]),
#  'split2_test_score': array([0.47427334, 0.71918566, 0.81086646, 0.8754089 , 0.87371673,
#         0.81442776, 0.81613366, 0.81204337, 0.86596056, 0.80077881,
#         0.78931063]),
#  'split3_test_score': array([0.28740699, 0.58456749, 0.77178006, 0.66714298, 0.74621508,
#         0.76188071, 0.67441598, 0.62750165, 0.67150289, 0.67277794,
#         0.67277794]),
#  'split4_test_score': array([0.45874556, 0.73797834, 0.7191523 , 0.80553096, 0.7740896 ,
#         0.77372099, 0.79206406, 0.74839762, 0.74547032, 0.64948029,
#         0.64948029]),
#  'mean_test_score': array([0.37114956, 0.63935681, 0.66637708, 0.62031146, 0.62752295,
#         0.61938367, 0.58407252, 0.61864589, 0.6246038 , 0.55711672,
#         0.51762316]),
#  'std_test_score': array([0.13601023, 0.1528293 , 0.23565266, 0.3417727 , 0.36997492,
#         0.33797664, 0.30093493, 0.27021987, 0.2661849 , 0.34607284,
#         0.32699276]),
#  'rank_test_score': array([11,  2,  1,  5,  3,  6,  8,  7,  4,  9, 10])}

# %%
print(model.best_params_,model.best_score_,model.best_estimator_)
# Out:
# {'max_depth': 3} 0.6663770843933408 DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=3,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
#Grid search model to predict as well


GSCV=model.predict(X_test)


from sklearn import metrics


print("Grid search CV Test Accuracy:",metrics.r2_score(y_test, GSCV))
# Out:
# Grid search CV Accuracy: 0.6576597447116712
