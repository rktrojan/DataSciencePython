# %%
import pgeocode

# %%
nomi = pgeocode.Nominatim('In')


nomi.query_postal_code("251001")
# Out:
# postal_code                                                  251001
# country_code                                                     IN
# place_name        Nirmana, Brahmpuri, Gandhi Colony, Barwala, Ha...
# state_name                                            Uttar Pradesh
# state_code                                                       36
# county_name                                           Muzaffarnagar
# county_code                                                     133
# community_name                                        Muzaffarnagar
# community_code                                                  NaN
# latitude                                                    29.3825
# longitude                                                    77.659
# accuracy                                                          4
# Name: 0, dtype: object

# %%
nomi.query_postal_code("251002")
# Out:
# postal_code                                                  251002
# country_code                                                     IN
# place_name        Shamli Road, Prempuri, Khala Par, Muzaffar Nag...
# state_name                                            Uttar Pradesh
# state_code                                                       36
# county_name                                           Muzaffarnagar
# county_code                                                     133
# community_name                                        Muzaffarnagar
# community_code                                                  NaN
# latitude                                                    28.9809
# longitude                                                   77.6691
# accuracy                                                          3
# Name: 0, dtype: object

# %%
nomi.query_postal_code("75013").longitude
# Out:
# 2.35245

# %%
HAVERSINE FORMULA
FEATURE

# %%
from haversine import haversine

# %%
from haversine import haversine
haversine((29.385, 77.659),(28.9809, 77.6691), unit='mi')
# Out:
# 27.92729745869148

# %%
dist = pgeocode.GeoDistance('fr')

dist.query_postal_code("75013", "69006")
# Out:
# 389.2183901641009

# %%
dist = pgeocode.GeoDistance('In')
dist.query_postal_code("110003" ,"251002")
# Out:
# 57.27793179650987

# %%
dist = pgeocode.GeoDistance('US')
dist.query_postal_code("60634", "60636")
# Out:
# 22.147845045437563

# %%
import pandas as pd


dt = pd.read_csv("https://raw.githubusercontent.com/rylativity/identifying_wnv_locations-raw_repo-/master/kaggle_data/train.csv")

# %%
dt
# Out:
#              Date                                            Address  \
# 0      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2      2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# ...           ...                                                ...
# 10501  2013-09-26      5100 West 72nd Street, Chicago, IL 60638, USA
# 10502  2013-09-26    5800 North Ridge Avenue, Chicago, IL 60660, USA
# 10503  2013-09-26  1700 North Ashland Avenue, Chicago, IL 60622, USA
# 10504  2013-09-26   7100 North Harlem Avenue, Chicago, IL 60631, USA
# 10505  2013-09-26      4200 West 65th Street, Chicago, IL 60621, USA
#
#                       Species  Block           Street  Trap  \
# 0      CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# ...

# %%
for i in dt.Address:
    print(i.split(","))
    print(i.split(",")[2][4:])
# Out:
# ['4100 North Oak Park Avenue', ' Chicago', ' IL 60634', ' USA']
# 60634
# ['4100 North Oak Park Avenue', ' Chicago', ' IL 60634', ' USA']
# 60634
# ['6200 North Mandell Avenue', ' Chicago', ' IL 60646', ' USA']
# 60646
# ['7900 West Foster Avenue', ' Chicago', ' IL 60656', ' USA']
# 60656
# ['7900 West Foster Avenue', ' Chicago', ' IL 60656', ' USA']
# 60656
# ['1500 West Webster Avenue', ' Chicago', ' IL 60614', ' USA']
# 60614
# ['2500 West Grand Avenue', ' Chicago', ' IL 60654', ' USA']
# 60654
# ['1100 Roosevelt Road', ' Chicago', ' IL 60608', ' USA']
# 60608
# ['1100 Roosevelt Road', ' Chicago', ' IL 60608', ' USA']
# 60608
# ['1100 West Chicago Avenue', ' Chicago', ' IL 60642', ' USA']
# 60642
# ['2100 North Stave Street', ' Chicago', ' IL 60647', ' USA']
# 60647
# ['2200 North Cannon Drive', ' Chicago', ' IL 60614', ' USA']
# 60614
# ['2200 North Cannon Drive', ' Chicago', ' IL 60614', ' USA']
# 60614
# ['2200 West 113th Street', ' Chicago', ' IL 60643', ' USA']
# 60643
# ...

# %%
dt["nn"]= dt["Address"].apply(lambda i: i.split(","))

# %%
dt
# Out:
#              Date                                            Address  \
# 0      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2      2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# ...           ...                                                ...
# 10501  2013-09-26      5100 West 72nd Street, Chicago, IL 60638, USA
# 10502  2013-09-26    5800 North Ridge Avenue, Chicago, IL 60660, USA
# 10503  2013-09-26  1700 North Ashland Avenue, Chicago, IL 60622, USA
# 10504  2013-09-26   7100 North Harlem Avenue, Chicago, IL 60631, USA
# 10505  2013-09-26      4200 West 65th Street, Chicago, IL 60621, USA
#
#                       Species  Block           Street  Trap  \
# 0      CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# ...

# %%
dist = pgeocode.GeoDistance('US')

# %%
for i in dt["nn"]:
    print(i[0][4:], dist.query_postal_code(i[0][4:], "60636"))
# Out:
#  North Oak Park Avenue nan
#  North Oak Park Avenue nan
#  North Mandell Avenue nan
#  West Foster Avenue nan
#  West Foster Avenue nan
#  West Webster Avenue nan
#  West Grand Avenue nan
#  Roosevelt Road nan
#  Roosevelt Road nan
#  West Chicago Avenue nan
#  North Stave Street nan
#  North Cannon Drive nan
#  North Cannon Drive nan
#  West 113th Street nan
#  West 113th Street nan
#  South Peoria Street nan
#  West 95th Street nan
#  West 89th Street nan
#  West 89th Street nan
# h Streeter Drive nan
# h Streeter Drive nan
#  North Oak Park Avenue nan
#  North Oakley Avenue nan
#  North Long Avenue nan
#  South Carpenter Street nan
#  North Oak Park Avenue nan
#  North Oak Park Avenue nan
#  North Oak Park Avenue nan
#  West Foster Avenue nan
#  West Foster Avenue nan
#  West Webster Avenue nan
#  West Webster Avenue nan
#  West Webster Avenue nan
#  West Grand Avenue nan
#  Roosevelt Road nan
#  Roosevelt Road nan
#  Roosevelt Road nan
#  West Chicago Avenue nan
# ...

# %%
#haversine formula

# https://en.wikipedia.org/wiki/Haversine_formula

# %%
#ERROR CELL

j=0

for i in dt.Address:
    print(j)
    dt.nn[j]=i.split(",")[2]
    j=j+1

# %%
dt.nn
# Out:
# 0        4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1        4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2        6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3          7900 West Foster Avenue, Chicago, IL 60656, USA
# 4          7900 West Foster Avenue, Chicago, IL 60656, USA
#                                ...
# 10501        5100 West 72nd Street, Chicago, IL 60638, USA
# 10502      5800 North Ridge Avenue, Chicago, IL 60660, USA
# 10503    1700 North Ashland Avenue, Chicago, IL 60622, USA
# 10504     7100 North Harlem Avenue, Chicago, IL 60631, USA
# 10505        4200 West 65th Street, Chicago, IL 60621, USA
# Name: nn, Length: 10506, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
#what is pyproj
import geopandas
import geoplot

# %%
world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)
boroughs = geopandas.read_file(
    geoplot.datasets.get_path('nyc_boroughs')
)
collisions = geopandas.read_file(
    geoplot.datasets.get_path('nyc_injurious_collisions')
)
